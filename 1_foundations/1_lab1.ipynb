# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity. Just give the name of the area"}]

# Then make the first call:

response = openai.responses.create(
    model="gpt-4o-mini",
    input=messages
)

# %%
business_area = response.output_text

question_for_pain_point = [
    {
        "role": "user",
        "content": f"Present 1 Biggest Pain Point in the industry - {business_area}. This pain point is something challenging that can be ripe for Agentic Solution"
    }
]

response_1 = openai.responses.create(
    model="gpt-4o-mini",
    input=question_for_pain_point
)

# %%
business_pain_point = response_1.output_text

print(business_pain_point)
# Out:
# One of the biggest pain points in healthcare management is **inefficient data interoperability across systems**.
#
# ### Explanation:
#
# Healthcare providers often use disparate systems for electronic health records (EHR), billing, patient management, and other functions. This lack of integration leads to fragmented patient information, making it difficult for providers to access comprehensive patient histories, leading to:
#
# - **Reduced Quality of Care**: Incomplete patient information can result in misdiagnoses or inappropriate treatments.
# - **Increased Administrative Burden**: Healthcare staff spend excessive time manually transferring data between systems, increasing operational costs.
# - **Patient Frustration**: Patients may experience delays and repeated tests due to unavailable or inaccessible health records.
#
# ### Ripe for Agentic Solution:
#
# Developing a **multi-platform interoperability solution** that seamlessly connects various EHR systems, simplifies data sharing, and ensures compliance with regulations can significantly enhance healthcare management. By leveraging advanced technologies like blockchain or APIs, an agentic solution can facilitate real-time data exchange, improve care coordination, and enhance patient outcomes. This would empower healthcare providers to have a holistic view of patient health, reducing errors and streamlining operations, ultimately leading to better healthcare experiences.

# %%
question_for_solution = [
    {
        "role": "user",
        "content": f"Based on the problems mentioned here \n {business_pain_point}, \n suggest an Agentic AI Solution"
    }
]

response_2 = openai.responses.create(
    model="gpt-4o-mini",
    input=question_for_solution
)

business_solution = response_2.output_text

print(business_solution)
# Out:
# ### Agentic AI Solution for Healthcare Data Interoperability
#
# #### Solution Name: **CareConnect AI**
#
# ### Overview:
# CareConnect AI is an advanced interoperability platform designed to bridge the gaps between disparate electronic health record (EHR) systems, enabling seamless data exchange, improving care coordination, and enhancing patient outcomes.
#
# ### Key Features:
#
# 1. **Real-Time Data Integration**:
#    - Utilize APIs and advanced data mapping techniques to facilitate real-time data syncing across multiple EHR systems.
#    - Implement a modular architecture that allows for easy integration of new data sources without disrupting existing workflows.
#
# 2. **Blockchain Security**:
#    - Leverage blockchain technology for secure data transactions, ensuring data integrity and patient privacy.
#    - Implement smart contracts to automate compliance with regulations such as HIPAA and GDPR.
#
# 3. **AI-Driven Data Harmonization**:
#    - Use AI algorithms to standardize data formats, ensuring that information from different systems can be accurately interpreted and utilized by healthcare providers.
#    - Employ natural language processing (NLP) to extract meaningful insights from unstructured data, such as doctor’s notes and patient reports.
#
# 4. **Patient-Centric Portal**:
#    - Create a user-friendly patient portal that allows patients to access their health records, schedule appointments, and communicate with healthcare providers.
#    - Implement a consent management system, enabling patients to control which providers can access their health information.
#
# 5. **Analytics and Reporting Dashboard**:
#    - Provide healthcare providers with an analytics dashboard that offers insights into patient data trends, outcomes, and operational efficiencies.
#    - Use machine learning to predict potential health risks based on historical data and suggest personalized care plans.
#
# 6. **Interoperability as a Service (IaaS)**:
#    - Offer a subscription-based service model for healthcare institutions to leverage the platform without heavy upfront investments.
#    - Continuous updates and enhancements to the platform, ensuring that users maintain cutting-edge technology and regulatory compliance.
#
# ### Benefits:
#
# - **Improved Quality of Care**: By enabling comprehensive access to patient histories, providers can make more informed decisions, leading to better diagnostic accuracy and treatment appropriateness.
# - **Reduced Administrative Burden**: Automating data transfers and reducing manual entry saves time and decreases operational costs, freeing up staff for patient care.
# - **Enhanced Patient Experience**: Patients benefit from quicker access to their records, streamlined scheduling, and reduced duplication of tests, leading to higher satisfaction.
#
# ### Implementation Steps:
#
# 1. **Stakeholder Engagement**:
#    - Collaborate with healthcare providers, patients, and regulatory bodies to understand their needs and concerns.
#
# 2. **Pilot Program**:
#    - Launch pilot implementations in select healthcare facilities to gather usage data and feedback.
#
# 3. **Iterative Development**:
#    - Utilize agile methodologies to iterate on features based on real-world usage and feedback from stakeholders.
#
# 4. **Full-Scale Deployment**:
#    - Gradually roll out the solution across different healthcare settings, ensuring thorough training and support for users.
#
# 5. **Continuous Improvement**:
#    - Regularly update the platform based on advances in technology, regulations, and user feedback.
#
# ### Conclusion:
# CareConnect AI stands to revolutionize healthcare interoperability by addressing the current pain points in data management. By creating a seamless, secure, and user-friendly solution, we can enhance care quality, reduce administrative burdens, and elevate patient experiences.
